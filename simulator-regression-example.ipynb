# %%
# %run linear-regression.ipynb

train_start = 10
train_end = 100

test_start = 10
test_end = 110

test_start2 = 110
test_end2 = 180

model = find_T(train_start, train_end, None, 1)

prediction = test_T(model, test_start, test_end, None, None)
print_prediction_results(prediction)

prediction = test_T(model, test_start2, test_end2, None, None)
print_prediction_results(prediction)
# Out:
# *****************************************************************************************************************
# Estimation Method:  1
# T=
#  [[ 5.35645039e-01 -1.44830546e+00  2.07713071e-01]
#  [-1.63076545e-03  9.88146712e-01 -3.47513147e-03]
#  [-1.95363169e+00 -7.26604255e+00  1.14675791e+00]]
# D=
#  [[0]
#  [0]
#  [0]]
# Training Period: [10, 100]
# Mean squared error: 0.07
# Coefficient of determination: 1.00
# *****************************************************************************************************************
# *****************************************************************************************************************
# Estimation Method:  1
# T=
#  [[ 5.35645039e-01 -1.44830546e+00  2.07713071e-01]
#  [-1.63076545e-03  9.88146712e-01 -3.47513147e-03]
#  [-1.95363169e+00 -7.26604255e+00  1.14675791e+00]]
# D=
#  [[0]
#  [0]
#  [0]]
# Training Period: [10, 100]
# Mean squared error: 0.20
# Coefficient of determination: 1.00
# *****************************************************************************************************************
