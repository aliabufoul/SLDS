# %%
# %run linear-regression.ipynb

train_start = 930 
train_end = 1250

test_start = 930
test_end = 1250

test_start2 = 1300
test_end2 = 2000

model = find_T(train_start, train_end, 1)

prediction = test_T(model, test_start, test_end)
print(white_noise(prediction.data_test, prediction.data_pred))
print_prediction_results(prediction)

prediction = test_T(model, test_start2, test_end2)
print(white_noise(prediction.data_test, prediction.data_pred))
print_prediction_results(prediction)
# Out:
# True
# *****************************************************************************************************************
# reg_method= 1
# T=
#  [[0.91372362 0.16257485 0.02412455]
#  [0.16010547 0.61147471 0.04509962]
#  [0.37966291 0.03889249 0.06661012]]
# D=
#  [[0]
#  [0]
#  [0]]
# Mean squared error: 7.29
# Coefficient of determination: 0.99
# 930 1250
# 0.001204286180703562
# -0.0002668987614895535
# -0.00327482477439478
# *****************************************************************************************************************
# False
# *****************************************************************************************************************
# reg_method= 1
# T=
#  [[0.91372362 0.16257485 0.02412455]
#  [0.16010547 0.61147471 0.04509962]
#  [0.37966291 0.03889249 0.06661012]]
# D=
#  [[0]
#  [0]
#  [0]]
# Mean squared error: 45.07
# Coefficient of determination: 0.97
# 930 1250
# 0.04012169661321374
# 0.43676211092274136
# -1.975624348579996
# ...
