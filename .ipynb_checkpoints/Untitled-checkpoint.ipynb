# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0, 5, 0.002)
size = len(t)
#print(size)
ecg = []
with open('911-7927-MDC_ECG_ELEC_POTL_II-500.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        ecg.append(float(row[1]))
    #print(ecg[:size])
    plt.plot(t,ecg[:size])
    plt.title('ECG')
    plt.xlabel('Time [sec]')
    plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0, 8, 0.008)
size = len(t)
#print(size)
bp = []
with open('911-7927-MDC_PRESS_BLD_ART_ABP-125.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        bp.append(float(row[1]))
    #print(t)
    #print(bp[:size])
    plt.plot(t,bp[:size])
    plt.title('Blood Pressure')
    plt.xlabel('Time [sec]')
    plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0, 10, 0.008)
size = len(t)
#print(size)
oxim = []
with open('911-7927-MDC_PULS_OXIM_PLETH-125.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        oxim.append(float(row[1]))
    #print(oxim[:size])
    plt.plot(t,oxim[:size])
    plt.title('Pulse Oximetry')
    plt.xlabel('Time [sec]')
    plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0, 10, 0.016)
size = len(t)
#print(size)
resp = []
with open('911-7927-MDC_RESP-62.5.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        resp.append(float(row[1]))
    #print(resp[:size])
    plt.plot(t,resp[:size])
    plt.title('Respiration')
    plt.xlabel('Time [sec]')
    plt.show()
