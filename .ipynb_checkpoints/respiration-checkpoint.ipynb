# %% [markdown]
# # Respiration

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
from scipy.misc import electrocardiogram
from scipy.signal import find_peaks
import os
from operator import itemgetter

# %%
t = np.arange(0, 5, 0.016)
size = len(t)
#print(size)
resp = []
for filename in os.listdir('samples'):
    if "MDC_RESP-62.5" in filename:
        print(filename+':')
        with open('samples/'+filename, 'r') as f:
            reader = csv.reader(f)
            for row in reader:
                resp.append(float(row[1]))
            #print(resp[:size])
            plt.plot(t,resp[:size])
            plt.title('Respiration')
            plt.xlabel('Time [sec]')
            plt.show()
            resp = []
# Out:
# 123456789-7885-MDC_RESP-62.5.csv:
# 123456789-7891-MDC_RESP-62.5.csv:
# 123456789-7899-MDC_RESP-62.5.csv:
# 123456789-7917-MDC_RESP-62.5.csv:
# 1887524-1979-MDC_RESP-62.5.csv:
# 1986951-5721-MDC_RESP-62.5.csv:
# 2175591-9564-MDC_RESP-62.5.csv:
# 2599720-3018-MDC_RESP-62.5.csv:
# 2672021-7143-MDC_RESP-62.5.csv:
# 2677398-3039-MDC_RESP-62.5.csv:
# 268269-2358-MDC_RESP-62.5.csv:
# 268269-2406-MDC_RESP-62.5.csv:
# 268269-2424-MDC_RESP-62.5.csv:
# 268269-2425-MDC_RESP-62.5.csv:
# 268269-2426-MDC_RESP-62.5.csv:
# 268269-2427-MDC_RESP-62.5.csv:
# 268269-2428-MDC_RESP-62.5.csv:
# 268269-2429-MDC_RESP-62.5.csv:
# 268269-2430-MDC_RESP-62.5.csv:
# 268269-2431-MDC_RESP-62.5.csv:
# 2750437-9318-MDC_RESP-62.5.csv:
# 2777531-2517-MDC_RESP-62.5.csv:
# 2784152-1242-MDC_RESP-62.5.csv:
# 2784152-1275-MDC_RESP-62.5.csv:
# 5047636-1580-MDC_RESP-62.5.csv:
# 5054901-2869-MDC_RESP-62.5.csv:
# 5070754-5089-MDC_RESP-62.5.csv:
