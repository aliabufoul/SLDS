# %%
# %run configuration.ipynb
# %run preprocessing/blood-pressure.ipynb
# %run preprocessing/heart-rate.ipynb
# %run preprocessing/respiration.ipynb
# %run linear-regression.ipynb

# %% [markdown]
# # Based on Simulated Patient Data

# %%
PATIENT_ID = "simulator"

train_start = 10
train_end = 100

test_start = 10
test_end = 180

model = find_T(train_start, train_end, 1)

prediction = test_T(model, test_start, test_end)
print_prediction_results(prediction)
# Out:
# *****************************************************************************************************************
# Estimation Method:  1
# T=
#  [[ 5.30698677e-01 -1.47776033e+00  2.01476370e-01]
#  [-1.73617899e-03  9.87774130e-01 -3.45409156e-03]
#  [-2.00824520e+00 -7.47439853e+00  1.14738078e+00]]
# D=
#  [[0]
#  [0]
#  [0]]
# Training Period: [10, 100]
# Mean squared error: 0.07
# Coefficient of determination: 1.00
# *****************************************************************************************************************

# %% [markdown]
# # Based on Real Patient Data

# %%
PATIENT_ID = "268269-2427"

train_start = 950
train_end = 1250

test_start = 950
test_end = 1250

test_start2 = 1300
test_end2 = 2000

model = find_T(train_start, train_end, 1)

prediction = test_T(model, test_start, test_end)
print_prediction_results(prediction)

prediction = test_T(model, test_start2, test_end2)
print_prediction_results(prediction)
# Out:
# *****************************************************************************************************************
# Estimation Method:  1
# T=
#  [[0.91955979 0.14927413 0.0247237 ]
#  [0.14725262 0.64184189 0.04255589]
#  [0.30530736 0.21011372 0.05696833]]
# D=
#  [[0]
#  [0]
#  [0]]
# Training Period: [950, 1250]
# Mean squared error: 7.65
# Coefficient of determination: 0.99
# *****************************************************************************************************************
# *****************************************************************************************************************
# Estimation Method:  1
# T=
#  [[0.91955979 0.14927413 0.0247237 ]
#  [0.14725262 0.64184189 0.04255589]
#  [0.30530736 0.21011372 0.05696833]]
# D=
#  [[0]
#  [0]
#  [0]]
# Training Period: [950, 1250]
# Mean squared error: 48.77
# Coefficient of determination: 0.96
# *****************************************************************************************************************
