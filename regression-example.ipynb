# %%
# %run linear-regression.ipynb

train_start = 950 
train_end = 1250

test_start = 950
test_end = 1250

test_start2 = 1300
test_end2 = 2000

model = find_T(train_start, train_end, 1)

prediction = test_T(model, test_start, test_end, None)
print_prediction_results(prediction)

prediction = test_T(model, test_start2, test_end2, None)
print_prediction_results(prediction)
# Out:
# *****************************************************************************************************************
# Estimation Method:  1
# T=
#  [[0.91955979 0.14927413 0.0247237 ]
#  [0.14725262 0.64184189 0.04255589]
#  [0.30530736 0.21011372 0.05696833]]
# D=
#  [[0]
#  [0]
#  [0]]
# Training Period: [950, 1250]
# Mean squared error: 7.65
# Coefficient of determination: 0.99
# *****************************************************************************************************************
# *****************************************************************************************************************
# Estimation Method:  1
# T=
#  [[0.91955979 0.14927413 0.0247237 ]
#  [0.14725262 0.64184189 0.04255589]
#  [0.30530736 0.21011372 0.05696833]]
# D=
#  [[0]
#  [0]
#  [0]]
# Training Period: [950, 1250]
# Mean squared error: 45.74
# Coefficient of determination: 0.97
# *****************************************************************************************************************
