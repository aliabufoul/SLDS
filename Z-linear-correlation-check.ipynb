# %% [markdown]
# # Checking linear corelation between the signals

# %%
# %run blood-pressure.ipynb
# %run heart-rate.ipynb
# %run respiration.ipynb

# %matplotlib notebook 

start_point = 930
end_point = 1250

time, bp_ = bp(start_point,end_point,0,0)
time, hr_ = hr(start_point,end_point,0,0)
time, rr_ = rr(start_point,end_point,0,0)

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(bp_[1:], bp_[:-1], c='r', marker='o')
ax.set_xlabel('blood-pressure [n]')
ax.set_ylabel('blood-pressure [n-1]')
plt.show()

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(bp_[1:], hr_[:-1], c='r', marker='o')
ax.set_xlabel('blood-pressure [n]')
ax.set_ylabel('heart-rate [n-1]')
plt.show()

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(bp_[1:], rr_[:-1], c='r', marker='o')
ax.set_xlabel('blood-pressure [n]')
ax.set_ylabel('respiration-rate [n-1]')
plt.show()

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(hr_[1:], bp_[:-1], c='r', marker='o')
ax.set_xlabel('heart-rate [n]')
ax.set_ylabel('blood-pressure [n-1]')
plt.show()

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(hr_[1:], hr_[:-1], c='r', marker='o')
ax.set_xlabel('heart-rate [n]')
ax.set_ylabel('heart-rate [n-1]')
plt.show()

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(hr_[1:], rr_[:-1], c='r', marker='o')
ax.set_xlabel('heart-rate [n]')
ax.set_ylabel('respiration-rate [n-1]')
plt.show()


fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(rr_[1:], bp_[:-1], c='r', marker='o')
ax.set_xlabel('respiration-rate [n]')
ax.set_ylabel('blood-pressure [n-1]')
plt.show()

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(rr_[1:], hr_[:-1], c='r', marker='o')
ax.set_xlabel('respiration-rate [n]')
ax.set_ylabel('heart-rate [n-1]')
plt.show()

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(rr_[1:], rr_[:-1], c='r', marker='o')
ax.set_xlabel('respiration-rate [n]')
ax.set_ylabel('respiration-rate [n-1]')
plt.show()


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(hr_, bp_, rr_, c='r', marker='o')
ax.set_xlabel('heart-rate')
ax.set_ylabel('blood-pressure')
ax.set_zlabel('respiration-rate')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
